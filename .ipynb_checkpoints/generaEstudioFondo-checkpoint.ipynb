# %%
# -*- coding: utf-8 -*-
# %pylab inline


# Importa librerías y define variables globales
import glob
import time
import locale
import calendar
from datetime import datetime, date
import decimal
import math
import pandas as pd
import calendar
import numpy as np
import matplotlib.pyplot as plt
from bokeh.io import output_file, show
from bokeh.plotting import figure

#Ojo: es clave establecer que el lenguaje local es el español

from docx import Document
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.text.run import Font, Run
from docx.shared import Inches,Pt

#locale.setlocale(locale.LC_ALL, 'esp_ESP')

dias_en_anno = 365.2425
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# esta función escribe la fecha en español
def texto_fecha(fecha):
    texto=str(fecha.day)+' de '+calendar.month_name[fecha.month]+' de '+str(fecha.year)
    return texto

# %%
def truncar(entero):
    x = int(entero * 1) / 1.0
    return x

# %%
truncar (12.99)
# Out:
# 12.0

# %%
def mesesHastaJubilar(genero,edad):
    if genero=='Masculino':
        meses=round(12*max(65-edad,0),0)
    else:
        meses=round(12*max(60-edad,0),0)
    return meses

# %%
# Acá se edita la ubicación donde están los datos de los futuros anexos
data_fondo='/Users/ggoni/Desktop/archivoFondo.xlsx'
df=pd.read_excel(data_fondo,sheets=1)
df.fechaNacimiento = pd.to_datetime(df.fechaNacimiento)
df.fechaContrato=pd.to_datetime(df.fechaContrato)

# %%
listaNombres=list(df.columns)

# %%
listaNombres=listaNombres+['escenario','fechaEscenario']

# %%
annos=list(range(2017,2028,1))
fechas=[datetime(anno,5,31) for anno in annos]

# %%
df_c=pd.DataFrame(columns=listaNombres)

# %%
for idFecha,fecha in enumerate(fechas):
    df_b=pd.DataFrame(columns=df.columns)
    df_b=df_b.append(df)
    df_b['escenario']=idFecha
    df_b['fechaEscenario']=fecha  
    df_c=df_c.append(df_b)

# %%
df_c.RBM=df_c.RBM.apply(round,0)
df_c['Edad']=(df_c.fechaEscenario-df_c.fechaNacimiento).astype('timedelta64[D]')/365
df_c['Edad_Truncada']=df_c.Edad.apply(truncar)
df_c['Antiguedad']=(df_c.fechaEscenario-df_c.fechaContrato).astype('timedelta64[D]')/365
df_c.Antiguedad=df_c.Antiguedad.apply(round,0)

# %%
df_c['mesesHastaJubilar']=np.vectorize(mesesHastaJubilar)(df_c.Genero,df_c.Edad)

# %%
df_c['PPA']=df_c.RBM*df_c.mesesHastaJubilar
df_c.PPA=df_c.mesesHastaJubilar*df_c.RBM*0.115
df_c.loc[df_c['alianza']!='SI','PPA']=0

# %%
df_c[['alianza','PPA','mesesHastaJubilar','RBM']]
# Out:
#      alianza          PPA  mesesHastaJubilar          RBM
# 0         SI       194426                1.0  1.69066e+06
# 1         NO            0              172.0  2.30315e+06
# 2         NO            0              119.0  1.35465e+06
# 3         NO            0                0.0  2.35818e+06
# 4         NO            0                0.0  3.11106e+06
# 5         NO            0              197.0  1.55653e+06
# 6         SI  5.80052e+06               63.0       800624
# 7         SI  6.42126e+06               83.0       672735
# 8         SI  1.52479e+07              115.0  1.15296e+06
# 9         NO            0              149.0       785182
# 10        SI  3.53618e+07               92.0  3.34232e+06
# 11        NO            0              152.0  1.46548e+06
# 12        NO            0              144.0       721965
# 13        NO            0                0.0   1.7438e+06
# 14        SI   9.7394e+06              104.0       814331
# 15        NO            0              158.0  2.05190e+06
# 16        NO            0              138.0  2.35692e+06
# 17        SI  1.42473e+06               13.0       952998
# 1188              224.0
# 1189              298.0
# 1190              185.0
# 1191              282.0
# 1192              137.0
# 1193                0.0
# 1194              205.0
# 1195              269.0
# 1196              190.0
# 1197              196.0
# 1198              250.0
# 1199              258.0
# 1200              272.0
# 1201                0.0
# 1202               73.0
# 1203              207.0
# 1204               53.0
# 1205              235.0
# 1206              312.0
# 1207              209.0
# 1208              336.0
# 1209                0.0
# 1210                0.0
# 1211                0.0
# 1212               53.0
# 1213                0.0
# 1214                0.0
# 1215              184.0
#
# [13376 rows x 6 columns]

# %%
df_c.pagoTotal.hist()
plt.show()

# %%
tabla=pd.DataFrame(pd.pivot_table(df_c,values='pagoTotal',index=['fechaEscenario'],
                                  fill_value=0,aggfunc=np.sum,columns=['Genero']))
tabla.index=tabla.index.year
tabla.loc[:,['Femenino','Masculino']] = 1./1e6*tabla.loc[:,['Femenino','Masculino']]
tabla.Femenino=tabla.Femenino.apply(round,0)
tabla.Masculino=tabla.Masculino.apply(round,0)
tabla
# Out:
# Genero Femenino Masculino
# 2017      18579     20061
# 2018      19218     20577
# 2019      19887     21129
# 2020      20587     21722
# 2021      21300     22347
# 2022      22041     23010
# 2023      22819     23721
# 2024      23628     24499
# 2025      24485     25313
# 2026      25403     26168
# 2027      26358     27062

# %%
df_c.to_excel('archivoFondoTotal.xlsx')

# %%
plot=figure()
plot.multi_line([tabla.index,tabla.index],[tabla.Femenino,tabla.Masculino],color=['pink','blue'],line_width=5)
show(plot)

# %%
# ?plot.multi_line

# %%
df_c.head(5)
# Out:
#     id    nPersona                           nombre idSociedad Sociedad aLIq  \
# 0  1.0  10000001.0        ABURTO QUINTANA ALEJANDRO       A000     ACHS   A1
# 1  2.0  10000002.0        ABARZA URRA HARRY EUSEBIO       A000     ACHS   A1
# 2  3.0  10000003.0       ACEVEDO LÓPEZ LUIS FLORIAN       A000     ACHS   A1
# 3  4.0  10000004.0  ADRIASOLA ROJAS VICTORIA ELIZAB       A000     ACHS   A1
# 4  5.0  10000005.0            ACUÑA LEIVA GUILLERMO       A000     ACHS   A1
#
#             Anomina          CC                descCC      codPos  \
# 0  ACHS Rol General  A0CC0SGS01  Subgcia GestionSalud  20000060.0
# 1  ACHS Rol General  A0HT0SSI01          Imagenología  20000720.0
# 2  ACHS Rol General  A0PLASEQ01       E.Clin P.L.Amer  20000628.0
# 3  ACHS Rol General  A0HT0SFA01           Farmacia HT  20000055.0
# 4  ACHS Rol General  A0HT0SIE01          Infectología  20000008.0
#
#       ...               RBM escenario fechaEscenario       Edad Edad_Truncada  \
# 0     ...       1.69066e+06       0.0     2017-05-31  64.898630          64.0
# 1     ...       2.30315e+06       0.0     2017-05-31  50.676712          50.0
# 2     ...       1.35465e+06       0.0     2017-05-31  55.106849          55.0
# 3     ...       2.35818e+06       0.0     2017-05-31  64.600000          64.0
# 4     ...       3.11106e+06       0.0     2017-05-31  68.638356          68.0
#
#   Antiguedad mesesHastaJubilar     PPA          IAS    pagoTotal
# 0         38               1.0  194426  6.59357e+07  6.61301e+07
# 1         25             172.0       0  5.98818e+07  5.98818e+07
# 2         24             119.0       0  3.38662e+07  3.38662e+07
# 3         31               0.0       0  7.54616e+07  7.54616e+07
# 4         28               0.0       0  9.02207e+07  9.02207e+07
#
# [5 rows x 27 columns]
